# %%
from my_package.utils import VisualizationPlots

# %%
g = VisualizationPlots(
    
)

# %%
import pandas as pd

# %%
test = pd.DataFrame([
    {'a': 1, 'b':2, 'c':3},
    {'a': 1, 'b':2, 'c':3},
    {'a': 1, 'b':2, 'c':3},
    {'a': 1, 'b':2, 'c':3},
])
test
# Out:
#    a  b  c
# 0  1  2  3
# 1  1  2  3
# 2  1  2  3
# 3  1  2  3

# %%
from my_package.utils import MappingLoadersFromCSV

test = MappingLoadersFromCSV(r'data\serias_from_images\csv_format\sup')

it = iter(test)
print(it)

print(next(it))
print(next(it))
print(next(it))
print(next(it))

# %%
test.series_dir
# Out:
# 'data\\serias_from_images\\csv_format\\sup'
